# %%
import sqlite3
import pandas as pd

# %%
# Criando uma conexão
con = sqlite3.connect('/content/drive/MyDrive/Colab Notebooks/Tweets_db/BD_Itaipava.db')

cur = con.cursor()

# %%
cur.execute('SELECT * FROM registros')

# %%
resultados = cur.fetchall()
resultados = pd.DataFrame(resultados)

# %%
resultados.columns = ['texto','RT']

# %%
display(resultados)
# Out:
#    texto RT
# 0     oi  1
# 1  teste  1
# 2    foi  1
